# %% [markdown]
# <a href="https://colab.research.google.com/github/AntonioFernandesdeCampos/projetos-legais/blob/main/In%C3%ADcio_Projeto_We_Clever.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas_profiling import ProfileReport

# %%
dataset = pd.read_csv('/content/Base DNC - Status.csv')

# %%
dataset
# Out:
#          Status  GH DtUltimaAutorizacaoAprovada Safra_DtUltAutAprovada  \
# 0        Recusa   7                  21/08/2022                08/2022
# 1        Recusa   7                  02/07/2022                07/2022
# 2        Recusa   5                  15/08/2022                08/2022
# 3        Recusa   5                  31/08/2022                08/2022
# 4     Conversão   6                  22/08/2022                08/2022
# ...         ...  ..                         ...                    ...
# 7221     Recusa   7                  29/09/2022                 202209
# 7222  Conversão   6                  15/09/2022                 202209
# 7223     Recusa   5                  29/09/2022                 202209
# 7224  Conversão   4                  30/09/2022                 202209
# 7225  Conversão   5                  25/09/2022                 202209
#
#       DdVencimentoFatura FlAcordoAndamento FlContaCartaoAptaTransacao  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7226 entries, 0 to 7225
# Data columns (total 82 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Status                          7226 non-null   object
#  1   GH                              7226 non-null   int64
#  2   DtUltimaAutorizacaoAprovada     7226 non-null   object
#  3   Safra_DtUltAutAprovada          7226 non-null   object
#  4   DdVencimentoFatura              7226 non-null   int64
#  5   FlAcordoAndamento               7226 non-null   object
#  6   FlContaCartaoAptaTransacao      7226 non-null   object
#  7   FlContaCartaoCancelada          7226 non-null   object
#  8   NmEstadoContaCartao             7226 non-null   object
#  9   flag_conta_ativa                7226 non-null   int64
#  10  DtAberturaContaCartao           7226 non-null   object
#  11  Safra_DtAberturaConta           7226 non-null   int64
# ...

# %%
dataset.head()
# Out:
#       Status  GH DtUltimaAutorizacaoAprovada Safra_DtUltAutAprovada  \
# 0     Recusa   7                  21/08/2022                08/2022
# 1     Recusa   7                  02/07/2022                07/2022
# 2     Recusa   5                  15/08/2022                08/2022
# 3     Recusa   5                  31/08/2022                08/2022
# 4  Conversão   6                  22/08/2022                08/2022
#
#    DdVencimentoFatura FlAcordoAndamento FlContaCartaoAptaTransacao  \
# 0                  17                 N                          S
# 1                  15                 N                          S
# 2                  11                 N                          S
# 3                  11                 N                          S
# 4                  11                 N                          S
#
#   FlContaCartaoCancelada NmEstadoContaCartao  flag_conta_ativa  ... FlGCU  \
# 0                      N               ATIVA                 1  ...     N
# ...

# %%
dataset.tail()
# Out:
#          Status  GH DtUltimaAutorizacaoAprovada Safra_DtUltAutAprovada  \
# 7221     Recusa   7                  29/09/2022                 202209
# 7222  Conversão   6                  15/09/2022                 202209
# 7223     Recusa   5                  29/09/2022                 202209
# 7224  Conversão   4                  30/09/2022                 202209
# 7225  Conversão   5                  25/09/2022                 202209
#
#       DdVencimentoFatura FlAcordoAndamento FlContaCartaoAptaTransacao  \
# 7221                  24                 N                          S
# 7222                  20                 N                          S
# 7223                  24                 N                          S
# 7224                  24                 N                          S
# 7225                  18                 N                          S
#
#      FlContaCartaoCancelada NmEstadoContaCartao  flag_conta_ativa  ... FlGCU  \
# ...

# %%
dataset['Status'] == 'Conversão'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 7221    False
# 7222     True
# 7223    False
# 7224     True
# 7225     True
# Name: Status, Length: 7226, dtype: bool

# %%
dataset.isna().sum()
# Out:
# Status                            0
# GH                                0
# DtUltimaAutorizacaoAprovada       0
# Safra_DtUltAutAprovada            0
# DdVencimentoFatura                0
#                                ...
# ult_GH_Prevent_Churn              0
# DsRamo                           87
# faixa_CLTV                        0
# ColScoreGroup                  1553
# Persona                           0
# Length: 82, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Status', 'GH', 'DtUltimaAutorizacaoAprovada', 'Safra_DtUltAutAprovada',
#        'DdVencimentoFatura', 'FlAcordoAndamento', 'FlContaCartaoAptaTransacao',
#        'FlContaCartaoCancelada', 'NmEstadoContaCartao', 'flag_conta_ativa',
#        'DtAberturaContaCartao', 'Safra_DtAberturaConta',
#        'DtPrimeiroDesbloqueio', 'Safra_DtPriDesbloqueio', 'DtPrimeiraCompra',
#        'Safra_DtPrimeiraCompra', 'DtAlteracaoLimiteContaCrtoGrl',
#        'Safra_DtAltLimiteContaGrl', 'QtDiasTempoInativo_Ajustado',
#        'VlLimiteContaCartaoGeralAntrr', 'QtDiasTempoInativo_Motivo',
#        'NmAgrpoEstdoCntaCrtoSgndoNvl', 'NmEstadoPlastico', 'flag_cartao_ativo',
#        'NuOrdemTitularidadePlastico', 'FLVERSAOVIGENTE', 'DtEmissaoPlastico',
#        'Safra_DtEmissaoPlastico', 'DtDesbloqueioPlastico',
#        'Safra_DtDesbloqueioPlastico', 'DtValidadePlastico',
#        'FlSeguroPerdaRoubo', 'FlSeguroPrtcoPrmdaClsco',
#        'FlSeguroProtecaoPrmdaPrm', 'FlSeguroProtecaoPrmdaEspcl',
# ...

# %%
dataset.duplicated().sum()
# Out:
# 2
